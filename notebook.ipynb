# %% [markdown]
# # Proyecto Machine Learning

# %% [markdown]
# ## Bibliotecas

# %%
import cv2
import ultralytics
from ultralytics import YOLO
from roboflow import Roboflow

import os

# %% [markdown]
# ## Carga del modelo

# %%
modelo = YOLO('yolov8n.pt')

# %%
ruta = "C:/Users/adria/Bootcamp/ML_The_Bridge/"

# %% [markdown]
# ## Prueba imagen

# %%
def comprobacion(ruta_imagen):
    imagen = modelo(ruta_imagen)
    imagen[0].show()

# %%
comprobacion(f"{ruta}/imagenes_prueba/prueba_2.jpg")
# Out:
# image 1/1 C:\Users\adria\Bootcamp\ML_The_Bridge\imagenes_prueba\prueba_2.jpg: 384x640 3 cars, 3 stop signs, 119.8ms
# Speed: 9.4ms preprocess, 119.8ms inference, 16.8ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ## Prueba vídeo

# %%
deteccion = modelo(
    source=f"{ruta}/imagenes_prueba/video_1.mp4", 
    save=True,              # Guarda el vídeo de salida
    conf=0.25,              # (Opcional) Mínimo umbral de confianza para mostrar la caja
    device=0                # (Opcional) Usa la GPU si está disponible (0) o 'cpu'
)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/462) C:\Users\adria\Bootcamp\ML_The_Bridge\imagenes_prueba\video_1.mp4: 384x640 1 person, 9 cars, 2 traffic lights, 52.3ms
# video 1/1 (frame 2/462) C:\Users\adria\Bootcamp\ML_The_Bridge\imagenes_prueba\video_1.mp4: 384x640 1 person, 9 cars, 1 traffic light, 56.7ms
# video 1/1 (frame 3/462) C:\Users\adria\Bootcamp\ML_The_Bridge\imagenes_prueba\video_1.mp4: 384x640 8 cars, 2 traffic lights, 58.2ms
# ...
